# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import datetime as dt
df = pd.read_csv('all_bikez_curated.csv')
df
# Out:
#          Brand                Model  Year                   Category  \
# 0      acabion      da vinci 650-vi  2011  Prototype / concept model
# 1      acabion              gtbo 55  2007                      Sport
# 2      acabion  gtbo 600 daytona-vi  2011  Prototype / concept model
# 3      acabion  gtbo 600 daytona-vi  2021  Prototype / concept model
# 4      acabion              gtbo 70  2007  Prototype / concept model
# ...        ...                  ...   ...                        ...
# 38538     azel             aries 50  2009                    Scooter
# 38539     azel             aries 50  2010                    Scooter
# 38540     azel            atila 125  2009           Enduro / offroad
# 38541     azel            atila 125  2010           Enduro / offroad
# 38542     azel        blackrose 250  2009           Custom / cruiser
#
#        Displacement (ccm)  Power (hp)  Engine cylinder Engine stroke  \
# ...

# %%
df.describe()
# Out:
#        Displacement (ccm)    Power (hp)  Fuel capacity (lts)  Dry weight (kg)  \
# count        37514.000000  26162.000000         31747.000000     22534.000000
# mean           552.327129     50.739787            13.284891       164.102858
# std            545.335993     52.067367             6.009697        85.052614
# min             25.000000      0.300000             0.500000        15.100000
# 25%            125.000000     12.000000             8.200000       105.000000
# 50%            397.000000     30.000000            13.500000       145.000000
# 75%            805.000000     77.000000            17.500000       199.600000
# max           8277.000000    804.000000            64.340000      1000.000000
#
#        Wheelbase (mm)  Seat height (mm)
# count    25530.000000      24225.000000
# mean      1423.003486        789.289659
# std        172.586414        105.437801
# min        725.000000         39.000000
# 25%       1321.000000        744.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38543 entries, 0 to 38542
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                38543 non-null  object
#  1   Model                38515 non-null  object
#  2   Year                 38543 non-null  object
#  3   Category             38543 non-null  object
#  4   Displacement (ccm)   37514 non-null  float64
#  5   Power (hp)           26162 non-null  float64
#  6   Engine cylinder      38527 non-null  object
#  7   Engine stroke        38532 non-null  object
#  8   Gearbox              32733 non-null  object
#  9   Fuel capacity (lts)  31747 non-null  float64
#  10  Fuel system          27893 non-null  object
#  11  Fuel control         22032 non-null  object
#  12  Cooling system       34322 non-null  object
#  13  Transmission type    32912 non-null  object
#  14  Dry weight (kg)      22534 non-null  float64
# ...

# %%
df['Category'].unique()
# Out:
# array(['Prototype / concept model', 'Sport', 'Scooter', 'ATV', 'Allround',
#        'Naked bike', 'Custom / cruiser', 'Cross / motocross',
#        'Super motard', 'Minibike, sport', 'Minibike, cross', 'Classic',
#        'Touring', 'Enduro / offroad', 'Trial', 'Unspecified category',
#        'Sport touring', 'Speedway'], dtype=object)

# %%
df['Displacement (ccm)'].fillna(df['Displacement (ccm)'].median(), inplace=True)
df['Power (hp)'].fillna(df['Power (hp)'].median(), inplace=True)

# %%
df['Fuel capacity (lts)'].fillna(df['Fuel capacity (lts)'].median(), inplace=True)
df['Dry weight (kg)'].fillna(df['Dry weight (kg)'].median(), inplace=True)

# %%
df['Wheelbase (mm)'].fillna(df['Wheelbase (mm)'].median(), inplace=True)
df['Seat height (mm)'].fillna(df['Seat height (mm)'].median(), inplace=True)

# %%
duplicate_rows = df[df.duplicated()]
duplicate_rows
# Out:
#          Brand                    Model  Year              Category  \
# 31114      sym                 nh x 125  2020            Naked bike
# 38484  zündapp               518 ks 100  1969                 Sport
# 38485  zündapp                bella 151  1955               Scooter
# 38486  zündapp                bella 151  1956               Scooter
# 38487  zündapp               bella 175s  1961               Scooter
# 38488   yamaha         rd 350 (6-speed)  1974               Classic
# 38489   yamaha  rd 350 (reduced effect)  1985  Unspecified category
# 38490   yamaha  rd 350 (reduced effect)  1986               Classic
#
#        Displacement (ccm)  Power (hp)  Engine cylinder Engine stroke  Gearbox  \
# 31114               124.1        10.1  Single cylinder   four-stroke  5-speed
# 38484               100.0        30.0  Single cylinder    two-stroke      NaN
# 38485               147.0         7.3  Single cylinder    two-stroke      NaN
# ...

# %%
duplicate_key = df[df.duplicated(subset=['Brand', 'Model', 'Year'], keep=False)]

# %%
#to drop duplicated values
df.drop_duplicates(subset=['Brand', 'Model', 'Year'], keep='first', inplace=True)
